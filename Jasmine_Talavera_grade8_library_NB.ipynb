# %% [markdown]
# <a href="https://colab.research.google.com/github/TimMTalavera/Jasmine-Talavera-grade8-library-Repo/blob/main/Jasmine_Talavera_grade8_library_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import firebase_admin
from firebase_admin import credentials, db
# Load the private key
cred = credentials.Certificate("/content/firebase_key.json")
# Initialize the app with your database URL
firebase_admin.initialize_app(cred, {
 "databaseURL": "https://grade8-json-db-default-rtdb.firebaseio.com/"
})
print("Firebase connected successfully!")

# %%
import json
with open("/content/books.json") as f:
 book = json.load(f)
print (book)
# Out:
# {'books': [{'id': 2001, 'title': 'Introduction to Python', 'author': 'Juan Dela Cruz', 'details': {'copies': 5, 'available': 3}}, {'id': 2002, 'title': 'Data Structures Basics', 'author': 'Maria Santos', 'details': {'copies': 4, 'available': 2}}, {'id': 2003, 'title': 'Web Development Essentials', 'author': 'Carlos Reyes', 'details': {'copies': 6, 'available': 6}}]}

# %%
import json
with open("/content/book.json", "r") as file:
 data = json.load(file)
print("JSON file loaded")
ref = db.reference("books") # Changed from "students" to "books"
for book_item in data["books"]: # Changed from data["students"] to data["books"]
 ref.child(str(book_item["id"])).set(book_item) # Using book_item["id"] assuming books have an 'id'
print("Data uploaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-489376593.py in <cell line: 0>()
#       1 import json
# ----> 2 with open("/content/book.json", "r") as file:
#       3  data = json.load(file)
#       4 print("JSON file loaded")
#       5 ref = db.reference("books") # Changed from "students" to "books"
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/book.json'

# %%
total_copies = 0
for book_info in book['books']:
    total_copies += book_info['details']['copies']
print(f"Total number of copies of all books in the library: {total_copies}")
# Out:
# Total number of copies of all books in the library: 15
